# %% [markdown]
# # LiveKit Agents: STT → Gemini Flash → Soprano TTS Pipeline
#
# This notebook implements a **fastest-path** voice agent pipeline using:
#
# | Component | Choice | Why |
# |-----------|--------|-----|
# | **STT** | sherpa-onnx streaming Zipformer small bilingual | int8 encoder/joiner + chunk size 96 for lower RTF |
# | **LLM** | Gemini Live API (gemini-2.5-flash) | TEXT-only modality for speed |
# | **TTS** | Soprano `infer_stream()` | True streaming audio (<15ms GPU latency) |
# | **VAD** | Silero VAD | Fast endpointing with `turn_detection="vad"` |
#
# ## Key Latency Optimizations
# - **No resampling on STT**: sherpa-onnx doesn't require 16kHz input
# - **Chunk size 96**: Lower RTF than smaller chunks
# - **Preemptive generation**: Enabled for perceived latency improvement
# - **Sentence-level TTS**: Incremental audio generation without waiting for full response

# %% [markdown]
# ## 1. Installation

# %%
# Install required packages
# !pip install "livekit-agents[google,silero]~=1.3"
# !pip install sherpa-onnx onnxruntime-gpu
# !pip install soprano-tts
# Out:
# Collecting livekit-agents~=1.3 (from livekit-agents[google,silero]~=1.3)
#   Downloading livekit_agents-1.3.12-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiofiles>=24 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (24.1.0)
# Requirement already satisfied: aiohttp~=3.10 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (3.13.3)
# Collecting av>=14.0.0 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading av-16.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi>=2025.6.15 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2026.1.4)
# Requirement already satisfied: click~=8.1 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (8.3.1)
# Collecting colorama>=0.4.6 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.17.0)
# Collecting eval-type-backport (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting livekit-api<2,>=1.0.7 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading livekit_api-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting livekit-blingfire~=1.0 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading livekit_blingfire-1.1.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Collecting livekit-protocol<2,>=1.1 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading livekit_protocol-1.1.2-py3-none-any.whl.metadata (883 bytes)
# Collecting livekit==1.0.23 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading livekit-1.0.23-py3-none-manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.6.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.0.2)
# Requirement already satisfied: openai>=1.99.2 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.15.0)
# Collecting opentelemetry-api~=1.39.0 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp~=1.39.0 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_exporter_otlp-1.39.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk~=1.39.0 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: prometheus-client>=0.22 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.24.1)
# Requirement already satisfied: protobuf>=3 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (5.29.5)
# Collecting psutil>=7.0 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading psutil-7.2.1-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pydantic<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.12.3)
# Requirement already satisfied: pyjwt>=2.0 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.10.1)
# Collecting sounddevice>=0.5 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading sounddevice-0.5.5-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.21.1)
# Collecting types-protobuf>=4 (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading types_protobuf-6.32.1.20251210-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (4.15.0)
# Requirement already satisfied: watchfiles>=1.0 in /usr/local/lib/python3.12/dist-packages (from livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.1.1)
# Collecting livekit-plugins-google>=1.3.12 (from livekit-agents[google,silero]~=1.3)
#   Downloading livekit_plugins_google-1.3.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting livekit-plugins-silero>=1.3.12 (from livekit-agents[google,silero]~=1.3)
#   Downloading livekit_plugins_silero-1.3.12-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.10->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.22.0)
# Requirement already satisfied: google-auth<3,>=2 in /usr/local/lib/python3.12/dist-packages (from livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (2.43.0)
# Requirement already satisfied: google-cloud-speech<3,>=2 in /usr/local/lib/python3.12/dist-packages (from livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (2.36.0)
# Collecting google-cloud-texttospeech<3,>=2.32 (from livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3)
#   Downloading google_cloud_texttospeech-2.34.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: google-genai>=1.55 in /usr/local/lib/python3.12/dist-packages (from livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (1.55.0)
# Collecting onnxruntime<=1.23.1,>=1.18 (from livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3)
#   Downloading onnxruntime-1.23.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (8.7.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.39.1 (from opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.39.1 (from opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.76.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests~=2.7 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.32.4)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.4.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from sounddevice>=0.5->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (13.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (4.9.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-speech<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (2.29.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-speech<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (1.27.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai>=1.55->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai>=1.55->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (15.0.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.99.2->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (3.23.0)
# Collecting coloredlogs (from onnxruntime<=1.23.1,>=1.18->livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<=1.23.1,>=1.18->livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime<=1.23.1,>=1.18->livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3) (25.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<=1.23.1,>=1.18->livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3) (1.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.15.1->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.15.1->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.19.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->sounddevice>=0.5->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.23)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-speech<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (1.71.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.15.1->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=2->livekit-plugins-google>=1.3.12->livekit-agents[google,silero]~=1.3) (0.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.39.1->opentelemetry-exporter-otlp~=1.39.0->livekit-agents~=1.3->livekit-agents[google,silero]~=1.3) (2.5.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<=1.23.1,>=1.18->livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<=1.23.1,>=1.18->livekit-plugins-silero>=1.3.12->livekit-agents[google,silero]~=1.3) (1.3.0)
# Downloading livekit_agents-1.3.12-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 42.6 MB/s eta 0:00:00a 0:00:01
# Downloading livekit-1.0.23-py3-none-manylinux_2_28_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 34.8 MB/s eta 0:00:0000:0100:01
# Downloading av-16.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 21.0 MB/s eta 0:00:00:00:0100:01
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading livekit_api-1.1.0-py3-none-any.whl (19 kB)
# Downloading livekit_blingfire-1.1.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.0/175.0 kB 20.0 MB/s eta 0:00:00
# Downloading livekit_plugins_google-1.3.12-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 4.5 MB/s eta 0:00:00
# Downloading livekit_plugins_silero-1.3.12-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 109.0 MB/s eta 0:00:0000:01
# Downloading livekit_protocol-1.1.2-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 11.9 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp-1.39.1-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 8.2 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 15.4 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 25.7 MB/s eta 0:00:00
# Downloading psutil-7.2.1-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 17.1 MB/s eta 0:00:00
# Downloading sounddevice-0.5.5-py3-none-any.whl (32 kB)
# Downloading types_protobuf-6.32.1.20251210-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.2 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading google_cloud_texttospeech-2.34.0-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 kB 14.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 33.0 MB/s eta 0:00:0000:0100:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: types-protobuf, psutil, opentelemetry-proto, livekit-blingfire, humanfriendly, eval-type-backport, colorama, av, sounddevice, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, livekit-protocol, livekit, coloredlogs, opentelemetry-semantic-conventions, onnxruntime, livekit-api, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, google-cloud-texttospeech, opentelemetry-exporter-otlp, livekit-agents, livekit-plugins-silero, livekit-plugins-google
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.37.0
#     Uninstalling opentelemetry-proto-1.37.0:
#       Successfully uninstalled opentelemetry-proto-1.37.0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.37.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.37.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.37.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.37.0
#     Uninstalling opentelemetry-api-1.37.0:
#       Successfully uninstalled opentelemetry-api-1.37.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.58b0
#     Uninstalling opentelemetry-semantic-conventions-0.58b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.58b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.37.0
#     Uninstalling opentelemetry-sdk-1.37.0:
#       Successfully uninstalled opentelemetry-sdk-1.37.0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-http
#     Found existing installation: opentelemetry-exporter-otlp-proto-http 1.37.0
#     Uninstalling opentelemetry-exporter-otlp-proto-http-1.37.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-http-1.37.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.21.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.39.1 which is incompatible.
# google-adk 1.21.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.
# Successfully installed av-16.1.0 colorama-0.4.6 coloredlogs-15.0.1 eval-type-backport-0.3.1 google-cloud-texttospeech-2.34.0 humanfriendly-10.0 livekit-1.0.23 livekit-agents-1.3.12 livekit-api-1.1.0 livekit-blingfire-1.1.0 livekit-plugins-google-1.3.12 livekit-plugins-silero-1.3.12 livekit-protocol-1.1.2 onnxruntime-1.23.1 opentelemetry-api-1.39.1 opentelemetry-exporter-otlp-1.39.1 opentelemetry-exporter-otlp-proto-common-1.39.1 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-exporter-otlp-proto-http-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 psutil-7.2.1 sounddevice-0.5.5 types-protobuf-6.32.1.20251210
# Collecting sherpa-onnx
#   Downloading sherpa_onnx-1.12.23-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 2.8 MB/s eta 0:00:00
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting sherpa-onnx-core==1.12.23 (from sherpa-onnx)
#   Downloading sherpa_onnx_core-1.12.23-py3-none-manylinux2014_x86_64.whl.metadata (629 bytes)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime-gpu) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Downloading sherpa_onnx-1.12.23-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 68.6 MB/s eta 0:00:00a 0:00:01
# Downloading sherpa_onnx_core-1.12.23-py3-none-manylinux2014_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 69.3 MB/s eta 0:00:00ta 0:00:01
# Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (300.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 MB 4.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: sherpa-onnx-core, sherpa-onnx, onnxruntime-gpu
# Successfully installed onnxruntime-gpu-1.23.2 sherpa-onnx-1.12.23 sherpa-onnx-core-1.12.23
# Collecting soprano-tts
#   Downloading soprano_tts-0.2.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (1.12.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (0.123.10)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (5.50.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (0.36.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (1.16.3)
# Requirement already satisfied: sounddevice in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (0.5.5)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (2.9.0+cu126)
# Requirement already satisfied: transformers>=4.51.0 in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (4.57.6)
# Collecting unidecode (from soprano-tts)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (0.40.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.12/dist-packages (from soprano-tts) (7.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.0->soprano-tts) (3.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->soprano-tts) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->soprano-tts) (1.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->soprano-tts) (7.2.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->soprano-tts) (0.50.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi->soprano-tts) (2.12.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->soprano-tts) (0.0.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (1.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (3.11.5)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.0.21)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.14.13)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->soprano-tts) (0.21.1)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio->soprano-tts) (15.0.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn->soprano-tts) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->soprano-tts) (0.16.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect->soprano-tts) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect->soprano-tts) (4.4.4)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from sounddevice->soprano-tts) (2.0.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->soprano-tts) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->soprano-tts) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->soprano-tts) (1.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->soprano-tts) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->soprano-tts) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->soprano-tts) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->soprano-tts) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->soprano-tts) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->soprano-tts) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.0->soprano-tts) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->soprano-tts) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->soprano-tts) (13.9.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->sounddevice->soprano-tts) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.51.0->soprano-tts) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.51.0->soprano-tts) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->soprano-tts) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->soprano-tts) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->soprano-tts) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->soprano-tts) (0.1.2)
# Downloading soprano_tts-0.2.0-py3-none-any.whl (35 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 11.3 MB/s eta 0:00:00
# Installing collected packages: unidecode, soprano-tts
# Successfully installed soprano-tts-0.2.0 unidecode-1.4.0

# %% [markdown]
# ## 2. Download Silero VAD Weights

# %%
# Download Silero VAD weights (required once)
# This uses the standard LiveKit plugin flow
# !python -c "from livekit.plugins import silero; silero.VAD.load()"

# %% [markdown]
# ## 3. Download Sherpa Model
#
# Use **`sherpa-onnx-streaming-zipformer-small-bilingual-zh-en-2023-02-16`** and prefer the **int8** files.
# The directory includes `64/` and `96/` chunk variants where larger chunk = lower RTF.

# %%
import os

# Download the sherpa model
SHERPA_MODEL_NAME = "sherpa-onnx-streaming-zipformer-small-bilingual-zh-en-2023-02-16"
SHERPA_MODEL_DIR = f"/content/{SHERPA_MODEL_NAME}"

if not os.path.exists(SHERPA_MODEL_DIR):
    # !wget -q https://github.com/k2-fsa/sherpa-onnx/releases/download/asr-models/{SHERPA_MODEL_NAME}.tar.bz2
    # !tar -xf {SHERPA_MODEL_NAME}.tar.bz2
    print(f"Model downloaded to: {SHERPA_MODEL_DIR}")
else:
    print(f"Model already exists at: {SHERPA_MODEL_DIR}")

os.environ["SHERPA_MODEL_DIR"] = SHERPA_MODEL_DIR
# Out:
# Model already exists at: /content/sherpa-onnx-streaming-zipformer-small-bilingual-zh-en-2023-02-16

# %% [markdown]
# ## 4. Environment Configuration

# %%
import os

# ============ REQUIRED: LiveKit Credentials ============
os.environ["LIVEKIT_URL"] = "wss://test-jllkasbg.livekit.cloud"  # Your LiveKit server URL
os.environ["LIVEKIT_API_KEY"] = "APIFnsAaWh3eFdR"  # Your API key
os.environ["LIVEKIT_API_SECRET"] = "WabCvkbupgaGfV7JQKBdZNDlYXuRFrr9jZcu7HTFdfG"  # Your API secret

# ============ REQUIRED: Google API Key ============
os.environ["GOOGLE_API_KEY"] = "AIzaSyD9sGx9FmvzIl7NtgU7vdwJVgs7NohSSqI"  # For Gemini

# ============ OPTIONAL: Tuning Parameters ============
os.environ["GEMINI_MODEL"] = "gemini-2.5-flash"  # Model to use
os.environ["GEMINI_TEMPERATURE"] = "0.3"  # Response temperature
os.environ["SYSTEM_PROMPT"] = "You are a concise, helpful voice assistant. Keep replies short unless asked."

# Soprano configuration
os.environ["SOPRANO_BACKEND"] = "lmdeploy"  # Use lmdeploy for speed
os.environ["SOPRANO_DEVICE"] = "cuda"  # GPU acceleration
os.environ["SOPRANO_CACHE_MB"] = "512"  # Cache size for T4
os.environ["SOPRANO_DECODER_BS"] = "2"  # Decoder batch size

# Sherpa configuration
os.environ["SHERPA_PROVIDER"] = "cuda"  # Use GPU
os.environ["SHERPA_NUM_THREADS"] = "2"  # Thread count

print("✅ Environment configured!")
# Out:
# ✅ Environment configured!

# %% [markdown]
# ## 5. Agent Implementation

# %%
import os
import re
import uuid
import numpy as np
from typing import AsyncIterable, Optional, List

from livekit import agents, rtc
from livekit.agents import Agent, AgentSession, ModelSettings, stt
from livekit.agents import cli
from livekit.agents.worker import WorkerOptions
from livekit.plugins import google, silero
from google.genai.types import Modality

import sherpa_onnx
from soprano import SopranoTTS


def _pick_existing(*paths: str) -> str:
    """Return the first path that exists."""
    for p in paths:
        if p and os.path.exists(p):
            return p
    raise FileNotFoundError(f"None of these paths exist: {paths}")


def _load_sherpa_recognizer(model_dir: str) -> sherpa_onnx.OnlineRecognizer:
    """
    Load sherpa-onnx recognizer with:
      - chunk size 96 (lower RTF)
      - int8 encoder + int8 joiner
    """
    # Prefer chunk=96 files when present
    base96 = os.path.join(model_dir, "96")
    base = base96 if os.path.isdir(base96) else model_dir

    tokens = _pick_existing(
        os.path.join(model_dir, "tokens.txt"),
        os.path.join(base, "tokens.txt"),
    )

    # Prefer int8 encoder/joiner when available
    encoder = _pick_existing(
        os.path.join(base, "encoder-epoch-99-avg-1.int8.onnx"),
        os.path.join(model_dir, "encoder-epoch-99-avg-1.int8.onnx"),
        os.path.join(base, "encoder-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "encoder-epoch-99-avg-1.onnx"),
    )
    decoder = _pick_existing(
        os.path.join(base, "decoder-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "decoder-epoch-99-avg-1.onnx"),
    )
    joiner = _pick_existing(
        os.path.join(base, "joiner-epoch-99-avg-1.int8.onnx"),
        os.path.join(model_dir, "joiner-epoch-99-avg-1.int8.onnx"),
        os.path.join(base, "joiner-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "joiner-epoch-99-avg-1.onnx"),
    )

    recognizer = sherpa_onnx.OnlineRecognizer.from_transducer(
        tokens=tokens,
        encoder=encoder,
        decoder=decoder,
        joiner=joiner,
        num_threads=int(os.getenv("SHERPA_NUM_THREADS", "2")),
        provider=os.getenv("SHERPA_PROVIDER", "cuda"),
        decoding_method="greedy_search",
        max_active_paths=4,
        enable_endpoint_detection=False,  # LiveKit VAD handles turns
    )
    return recognizer


print("✅ Helper functions defined!")
# Out:
# ✅ Helper functions defined!

# %%
class FastPipelineAgent(Agent):
    """Custom agent with sherpa-onnx STT and Soprano TTS nodes."""
    
    def __init__(self, *, sherpa_recognizer: sherpa_onnx.OnlineRecognizer, soprano: SopranoTTS):
        super().__init__()
        self._sherpa = sherpa_recognizer
        self._soprano = soprano
        # Sentence boundary splitter for incremental TTS
        self._sent_re = re.compile(r"(.+?[.!?]\s+|.+?\n+)", re.DOTALL)

    async def stt_node(
        self,
        audio: AsyncIterable[rtc.AudioFrame],
        model_settings: ModelSettings,
    ) -> Optional[AsyncIterable[stt.SpeechEvent]]:
        """Custom STT using sherpa-onnx streaming recognizer."""
        
        async def _run() -> AsyncIterable[stt.SpeechEvent]:
            stream = self._sherpa.create_stream()
            last_text = ""

            async for frame in audio:
                samples_i16 = np.frombuffer(frame.data, dtype=np.int16)
                samples_f32 = samples_i16.astype(np.float32) / 32768.0
                stream.accept_waveform(frame.sample_rate, samples_f32)

                while self._sherpa.is_ready(stream):
                    self._sherpa.decode_stream(stream)
                    r = self._sherpa.get_result(stream)
                    text = r if isinstance(r, str) else getattr(r, "text", "")
                    if text and text != last_text:
                        last_text = text

            # Finalize
            stream.input_finished()
            while self._sherpa.is_ready(stream):
                self._sherpa.decode_stream(stream)

            r = self._sherpa.get_result(stream)
            final_text = r if isinstance(r, str) else getattr(r, "text", "")

            if final_text.strip():
                yield stt.SpeechEvent(
                    type=stt.SpeechEventType.FINAL_TRANSCRIPT,
                    alternatives=[stt.SpeechData(text=final_text)],
                )

            yield stt.SpeechEvent(type=stt.SpeechEventType.END_OF_SPEECH, alternatives=[])

        return _run()

    async def tts_node(
        self,
        text: AsyncIterable[str],
        model_settings: ModelSettings,
    ) -> AsyncIterable[rtc.AudioFrame]:
        """Custom TTS using Soprano's infer_stream() for true streaming audio."""
        
        buffer = ""
        sample_rate = 32000  # Soprano outputs 32kHz
        channels = 1
        frame_ms = 20
        spf = int(sample_rate * frame_ms / 1000)  # samples per frame

        async def _emit_audio_from_pcm(pcm_f32: np.ndarray):
            """Convert float PCM to int16 frames."""
            pcm_i16 = np.clip(pcm_f32, -1.0, 1.0)
            pcm_i16 = (pcm_i16 * 32767.0).astype(np.int16)

            idx = 0
            n = pcm_i16.shape[0]
            while idx < n:
                chunk = pcm_i16[idx : idx + spf]
                if chunk.shape[0] < spf:
                    pad = np.zeros((spf - chunk.shape[0],), dtype=np.int16)
                    chunk = np.concatenate([chunk, pad], axis=0)
                idx += spf

                yield rtc.AudioFrame(
                    data=chunk.tobytes(),
                    sample_rate=sample_rate,
                    num_channels=channels,
                    samples_per_channel=spf,
                )

        async def _speak_sentence(sentence: str):
            """Stream audio for a single sentence."""
            stream = self._soprano.infer_stream(sentence, chunk_size=1)
            for chunk in stream:
                if isinstance(chunk, np.ndarray):
                    pcm = chunk.astype(np.float32)
                else:
                    pcm = np.asarray(chunk, dtype=np.float32)

                async for frame in _emit_audio_from_pcm(pcm):
                    yield frame

        async for delta in text:
            buffer += delta

            # Pull completed sentences fast
            out_sentences: List[str] = []
            while True:
                m = self._sent_re.match(buffer)
                if not m:
                    break
                s = m.group(1)
                out_sentences.append(s)
                buffer = buffer[len(s) :]

            for s in out_sentences:
                async for frame in _speak_sentence(s):
                    yield frame

        # Flush remainder
        if buffer.strip():
            async for frame in _speak_sentence(buffer):
                yield frame


print("✅ FastPipelineAgent class defined!")
# Out:
# ✅ FastPipelineAgent class defined!

# %%
def prewarm(proc: agents.JobProcess):
    """Prewarm models for faster first response."""
    
    # VAD: local CPU model for responsive turn detection
    proc.userdata["vad"] = silero.VAD.load(
        min_speech_duration=0.05,
        min_silence_duration=0.35,  # reduce end-of-turn latency
        force_cpu=True,
    )

    # Sherpa model
    sherpa_dir = os.environ["SHERPA_MODEL_DIR"]
    proc.userdata["sherpa"] = _load_sherpa_recognizer(sherpa_dir)

    # Soprano TTS
    proc.userdata["soprano"] = SopranoTTS(
        backend=os.getenv("SOPRANO_BACKEND", "lmdeploy"),
        device=os.getenv("SOPRANO_DEVICE", "cuda"),
        cache_size_mb=int(os.getenv("SOPRANO_CACHE_MB", "512")),
        decoder_batch_size=int(os.getenv("SOPRANO_DECODER_BS", "2")),
    )
    
    print("✅ Models prewarmed!")


async def entrypoint(ctx: agents.JobContext):
    """Main agent entrypoint."""
    
    vad = ctx.proc.userdata["vad"]
    sherpa_recognizer = ctx.proc.userdata["sherpa"]
    soprano = ctx.proc.userdata["soprano"]

    agent = FastPipelineAgent(sherpa_recognizer=sherpa_recognizer, soprano=soprano)

    session = AgentSession(
        # Fast turn detection
        turn_detection="vad",
        vad=vad,

        # Gemini Live API (text-only for speed)
        llm=google.realtime.RealtimeModel(
            model=os.getenv("GEMINI_MODEL", "gemini-2.5-flash"),
            modalities=[Modality.TEXT],
            instructions=os.getenv(
                "SYSTEM_PROMPT",
                "You are a concise, helpful voice assistant. Keep replies short unless asked.",
            ),
            temperature=float(os.getenv("GEMINI_TEMPERATURE", "0.3")),
        ),

        # Helps perceived latency
        preemptive_generation=True,
    )

    await session.start(agent=agent, room=ctx.room)


print("✅ Entrypoint and prewarm functions defined!")
# Out:
# ✅ Entrypoint and prewarm functions defined!

# %% [markdown]
# ## 6. Run the Agent
#
# ⚠️ **Note**: Running the agent requires a LiveKit server and proper credentials.
# The agent will connect to your LiveKit room and start processing audio.

# %%
# %%writefile livekit_soprano_agent.py
"""
LiveKit Agents (Python) STT → Gemini (Flash) → Soprano Pipeline
Fastest-path version with:
- STT: sherpa-onnx streaming Zipformer small bilingual (int8 encoder/joiner + chunk size 96)
- LLM: Gemini Live API via LiveKit Google plugin (gemini-2.5-flash, TEXT-only modality)
- TTS: Soprano infer_stream() (true streaming audio)
- Turn detection: Silero VAD + turn_detection="vad" for fast endpointing
- Preemptive generation: enabled
"""

"""LiveKit Agents: STT → Gemini Flash → Soprano TTS Pipeline"""

import os
import re
import uuid
import numpy as np
from typing import AsyncIterable, Optional, List

from livekit import agents, rtc
from livekit.agents import Agent, AgentSession, ModelSettings, stt
from livekit.agents import cli
from livekit.agents.worker import WorkerOptions
from livekit.plugins import google, silero
from google.genai.types import Modality

# --- Optional but recommended: ONNX Runtime GPU for sherpa-onnx on your T4 ---
# pip install onnxruntime-gpu

import sherpa_onnx  # pip install sherpa-onnx
from soprano import SopranoTTS  # pip install soprano-tts


def _pick_existing(*paths: str) -> str:
    for p in paths:
        if p and os.path.exists(p):
            return p
    raise FileNotFoundError(f"None of these paths exist: {paths}")


def _load_sherpa_recognizer(model_dir: str) -> sherpa_onnx.OnlineRecognizer:
    """
    Uses the small bilingual Zipformer model directory and prefers:
      - chunk size 96 (lower RTF)
      - int8 encoder + int8 joiner
    Model dir contains 64/96 subfolders where larger chunk => lower RTF.
    """
    # Prefer chunk=96 files when present (some packages place chunked variants in subfolders)
    base96 = os.path.join(model_dir, "96")
    base = base96 if os.path.isdir(base96) else model_dir

    tokens = _pick_existing(
        os.path.join(model_dir, "tokens.txt"),
        os.path.join(base, "tokens.txt"),
    )

    # Prefer int8 encoder/joiner when available
    encoder = _pick_existing(
        os.path.join(base, "encoder-epoch-99-avg-1.int8.onnx"),
        os.path.join(model_dir, "encoder-epoch-99-avg-1.int8.onnx"),
        os.path.join(base, "encoder-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "encoder-epoch-99-avg-1.onnx"),
    )
    decoder = _pick_existing(
        os.path.join(base, "decoder-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "decoder-epoch-99-avg-1.onnx"),
    )
    joiner = _pick_existing(
        os.path.join(base, "joiner-epoch-99-avg-1.int8.onnx"),
        os.path.join(model_dir, "joiner-epoch-99-avg-1.int8.onnx"),
        os.path.join(base, "joiner-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "joiner-epoch-99-avg-1.onnx"),
    )

    # NOTE: sherpa-onnx supports input sampling rates not necessarily 16k (so we avoid resampling for speed).
    # Provider "cuda" uses onnxruntime-gpu.
    recognizer = sherpa_onnx.OnlineRecognizer.from_transducer(
        tokens=tokens,
        encoder=encoder,
        decoder=decoder,
        joiner=joiner,
        num_threads=int(os.getenv("SHERPA_NUM_THREADS", "2")),
        provider=os.getenv("SHERPA_PROVIDER", "cuda"),  # "cuda" on your T4
        decoding_method="greedy_search",
        max_active_paths=4,
        enable_endpoint_detection=False,  # LiveKit VAD handles turns; keep this off for simplicity/latency
    )
    return recognizer


class FastPipelineAgent(Agent):
    def __init__(self, *, sherpa_recognizer: sherpa_onnx.OnlineRecognizer, soprano: SopranoTTS):
        super().__init__()
        self._sherpa = sherpa_recognizer
        self._soprano = soprano

        # Simple sentence boundary splitter for incremental TTS kickoff.
        # (Keeps latency low without waiting for the full assistant message.)
        self._sent_re = re.compile(r"(.+?[.!?]\s+|.+?\n+)", re.DOTALL)

    async def stt_node(
        self,
        audio: AsyncIterable[rtc.AudioFrame],
        model_settings: ModelSettings,
    ) -> Optional[AsyncIterable[stt.SpeechEvent]]:
        async def _run() -> AsyncIterable[stt.SpeechEvent]:
            stream = self._sherpa.create_stream()
            last_text = ""

            async for frame in audio:
                # LiveKit frames are PCM bytes; interpret as int16 mono/whatever channeling is provided.
                # If you know your input is stereo, downmix in the client or upstream track settings for best accuracy.
                samples_i16 = np.frombuffer(frame.data, dtype=np.int16)
                samples_f32 = samples_i16.astype(np.float32) / 32768.0

                stream.accept_waveform(frame.sample_rate, samples_f32)

                while self._sherpa.is_ready(stream):
                    self._sherpa.decode_stream(stream)
                    r = self._sherpa.get_result(stream)
                    text = r if isinstance(r, str) else getattr(r, "text", "")
                    if text and text != last_text:
                        last_text = text

            # finalize
            stream.input_finished()
            while self._sherpa.is_ready(stream):
                self._sherpa.decode_stream(stream)

            r = self._sherpa.get_result(stream)
            final_text = r if isinstance(r, str) else getattr(r, "text", "")

            if final_text.strip():
                yield stt.SpeechEvent(
                    type=stt.SpeechEventType.FINAL_TRANSCRIPT,
                    alternatives=[stt.SpeechData(text=final_text)],
                )

            yield stt.SpeechEvent(type=stt.SpeechEventType.END_OF_SPEECH, alternatives=[])

        return _run()

    async def tts_node(
        self,
        text: AsyncIterable[str],
        model_settings: ModelSettings,
    ) -> AsyncIterable[rtc.AudioFrame]:
        """
        Uses Soprano's official infer_stream() for streaming audio (<15ms GPU latency claim).
        The OpenAI-compatible HTTP endpoint is currently non-streaming, so we avoid it.
        """
        buffer = ""
        sample_rate = 32000  # Soprano outputs 32kHz
        channels = 1
        frame_ms = 20
        spf = int(sample_rate * frame_ms / 1000)  # samples per frame

        async def _emit_audio_from_pcm(pcm_f32: np.ndarray):
            # Convert float [-1,1] -> int16 PCM
            pcm_i16 = np.clip(pcm_f32, -1.0, 1.0)
            pcm_i16 = (pcm_i16 * 32767.0).astype(np.int16)

            # chunk into ~20ms frames
            idx = 0
            n = pcm_i16.shape[0]
            while idx < n:
                chunk = pcm_i16[idx : idx + spf]
                if chunk.shape[0] < spf:
                    # pad last frame
                    pad = np.zeros((spf - chunk.shape[0],), dtype=np.int16)
                    chunk = np.concatenate([chunk, pad], axis=0)
                idx += spf

                yield rtc.AudioFrame(
                    data=chunk.tobytes(),
                    sample_rate=sample_rate,
                    num_channels=channels,
                    samples_per_channel=spf,
                )

        async def _speak_sentence(sentence: str):
            # Soprano streaming inference generator
            # It yields audio chunks; handle common return types robustly.
            stream = self._soprano.infer_stream(sentence, chunk_size=1)
            for chunk in stream:
                if isinstance(chunk, np.ndarray):
                    pcm = chunk.astype(np.float32)
                else:
                    pcm = np.asarray(chunk, dtype=np.float32)

                async for frame in _emit_audio_from_pcm(pcm):
                    yield frame

        async for delta in text:
            buffer += delta

            # Pull completed sentences fast (don't wait for full message)
            out_sentences: List[str] = []
            while True:
                m = self._sent_re.match(buffer)
                if not m:
                    break
                s = m.group(1)
                out_sentences.append(s)
                buffer = buffer[len(s) :]

            for s in out_sentences:
                async for frame in _speak_sentence(s):
                    yield frame

        # Flush remainder
        if buffer.strip():
            async for frame in _speak_sentence(buffer):
                yield frame


def prewarm(proc: agents.JobProcess):
    # VAD: local CPU model, recommended for responsive turn detection.
    proc.userdata["vad"] = silero.VAD.load(
        min_speech_duration=0.05,
        min_silence_duration=0.35,  # reduce end-of-turn latency a bit
        force_cpu=True,
    )

    # Sherpa model
    sherpa_dir = os.environ["SHERPA_MODEL_DIR"]
    proc.userdata["sherpa"] = _load_sherpa_recognizer(sherpa_dir)

    # Soprano: use lmdeploy backend if available for speed; adjust cache/batch for your 15GB T4.
    # (From Soprano docs: cache_size_mb and decoder_batch_size can improve speed.)
    proc.userdata["soprano"] = SopranoTTS(
        backend=os.getenv("SOPRANO_BACKEND", "lmdeploy"),
        device=os.getenv("SOPRANO_DEVICE", "cuda"),
        cache_size_mb=int(os.getenv("SOPRANO_CACHE_MB", "512")),
        decoder_batch_size=int(os.getenv("SOPRANO_DECODER_BS", "2")),
    )


async def entrypoint(ctx: agents.JobContext):
    vad = ctx.proc.userdata["vad"]
    sherpa_recognizer = ctx.proc.userdata["sherpa"]
    soprano = ctx.proc.userdata["soprano"]

    agent = FastPipelineAgent(sherpa_recognizer=sherpa_recognizer, soprano=soprano)

    session = AgentSession(
        # Fast turn detection
        turn_detection="vad",
        vad=vad,

        # Gemini Live API as text-only (half-cascade); model defaults to gemini-2.5-flash and can be specified.
        llm=google.realtime.RealtimeModel(
            model=os.getenv("GEMINI_MODEL", "gemini-2.5-flash"),
            modalities=[Modality.TEXT],
            instructions=os.getenv(
                "SYSTEM_PROMPT",
                "You are a concise, helpful voice assistant. Keep replies short unless asked.",
            ),
            temperature=float(os.getenv("GEMINI_TEMPERATURE", "0.3")),
        ),

        # Helps perceived latency in some scenarios.
        preemptive_generation=True,
    )

    await session.start(agent=agent, room=ctx.room)


if __name__ == "__main__":
    cli.run_app(
        WorkerOptions(
            entrypoint_fnc=entrypoint,
            prewarm_fnc=prewarm,
        )
    )
# Out:
# Overwriting livekit_soprano_agent.py

# %%
# !python livekit_soprano_agent.py start
# Out:
# {"message": "starting worker", "level": "INFO", "name": "livekit.agents", "version": "1.3.12", "rtc-version": "1.0.23", "timestamp": "2026-01-24T09:27:31.317023+00:00"}
# {"message": "preloading plugins", "level": "INFO", "name": "livekit.agents", "packages": ["livekit.plugins.google", "livekit.plugins.silero", "av"], "timestamp": "2026-01-24T09:27:31.317196+00:00"}
# {"message": "HTTP server listening on :8081", "level": "INFO", "name": "livekit.agents", "timestamp": "2026-01-24T09:27:31.318505+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9086, "timestamp": "2026-01-24T09:27:42.368682+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9088, "timestamp": "2026-01-24T09:27:42.371219+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9086, "timestamp": "2026-01-24T09:27:52.369979+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9086, "timestamp": "2026-01-24T09:27:52.370182+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9088, "timestamp": "2026-01-24T09:27:52.375113+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9088, "timestamp": "2026-01-24T09:27:52.375257+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 870.67578125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9088, "timestamp": "2026-01-24T09:27:52.375672+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9086, "timestamp": "2026-01-24T09:27:52.424446+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9088, "timestamp": "2026-01-24T09:27:52.428923+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9086, "timestamp": "2026-01-24T09:27:52.871089+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9088, "timestamp": "2026-01-24T09:27:52.880689+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9140, "timestamp": "2026-01-24T09:27:52.915443+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9142, "timestamp": "2026-01-24T09:27:52.921429+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9140, "timestamp": "2026-01-24T09:28:02.916399+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9140, "timestamp": "2026-01-24T09:28:02.916624+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9142, "timestamp": "2026-01-24T09:28:02.922533+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9142, "timestamp": "2026-01-24T09:28:02.922674+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9140, "timestamp": "2026-01-24T09:28:02.972921+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9142, "timestamp": "2026-01-24T09:28:02.976294+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9140, "timestamp": "2026-01-24T09:28:03.418757+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9142, "timestamp": "2026-01-24T09:28:03.423131+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9196, "timestamp": "2026-01-24T09:28:03.474233+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9198, "timestamp": "2026-01-24T09:28:03.477470+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9196, "timestamp": "2026-01-24T09:28:13.475433+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9196, "timestamp": "2026-01-24T09:28:13.475650+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9198, "timestamp": "2026-01-24T09:28:13.479115+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9198, "timestamp": "2026-01-24T09:28:13.479249+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 881.0546875, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9198, "timestamp": "2026-01-24T09:28:13.479628+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9196, "timestamp": "2026-01-24T09:28:13.534160+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9198, "timestamp": "2026-01-24T09:28:13.534770+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9196, "timestamp": "2026-01-24T09:28:13.978003+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9198, "timestamp": "2026-01-24T09:28:13.980163+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9248, "timestamp": "2026-01-24T09:28:14.025498+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9250, "timestamp": "2026-01-24T09:28:14.030443+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9248, "timestamp": "2026-01-24T09:28:23.899338+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 831.88671875, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9248, "timestamp": "2026-01-24T09:28:23.902374+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9303, "timestamp": "2026-01-24T09:28:23.982313+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9250, "timestamp": "2026-01-24T09:28:24.032174+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9250, "timestamp": "2026-01-24T09:28:24.032607+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 879.46484375, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9250, "timestamp": "2026-01-24T09:28:24.033126+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9250, "timestamp": "2026-01-24T09:28:24.160664+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9250, "timestamp": "2026-01-24T09:28:24.533387+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9310, "timestamp": "2026-01-24T09:28:24.576231+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9303, "timestamp": "2026-01-24T09:28:33.207442+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 833.3828125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9303, "timestamp": "2026-01-24T09:28:33.211128+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9353, "timestamp": "2026-01-24T09:28:33.310872+00:00"}
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9310, "timestamp": "2026-01-24T09:28:33.856179+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 833.3828125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9310, "timestamp": "2026-01-24T09:28:33.857183+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9362, "timestamp": "2026-01-24T09:28:33.914915+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9353, "timestamp": "2026-01-24T09:28:43.313376+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9353, "timestamp": "2026-01-24T09:28:43.313571+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9353, "timestamp": "2026-01-24T09:28:43.366461+00:00"}
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9362, "timestamp": "2026-01-24T09:28:43.770653+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9353, "timestamp": "2026-01-24T09:28:43.814687+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9416, "timestamp": "2026-01-24T09:28:43.870408+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9418, "timestamp": "2026-01-24T09:28:43.874262+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9416, "timestamp": "2026-01-24T09:28:53.872197+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9416, "timestamp": "2026-01-24T09:28:53.872415+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 878.125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9416, "timestamp": "2026-01-24T09:28:53.872928+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9418, "timestamp": "2026-01-24T09:28:53.877151+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9418, "timestamp": "2026-01-24T09:28:53.877282+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9416, "timestamp": "2026-01-24T09:28:53.930763+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9418, "timestamp": "2026-01-24T09:28:53.931543+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9416, "timestamp": "2026-01-24T09:28:54.373107+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9418, "timestamp": "2026-01-24T09:28:54.378286+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9470, "timestamp": "2026-01-24T09:28:54.435509+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9472, "timestamp": "2026-01-24T09:28:54.441585+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9470, "timestamp": "2026-01-24T09:29:04.436661+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9470, "timestamp": "2026-01-24T09:29:04.436858+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9472, "timestamp": "2026-01-24T09:29:04.443194+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9472, "timestamp": "2026-01-24T09:29:04.443337+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9470, "timestamp": "2026-01-24T09:29:04.496940+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9472, "timestamp": "2026-01-24T09:29:04.498466+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9470, "timestamp": "2026-01-24T09:29:04.938795+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9472, "timestamp": "2026-01-24T09:29:04.945065+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9526, "timestamp": "2026-01-24T09:29:04.999805+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9528, "timestamp": "2026-01-24T09:29:05.007454+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9528, "timestamp": "2026-01-24T09:29:14.503197+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 831.4921875, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9528, "timestamp": "2026-01-24T09:29:14.508638+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9576, "timestamp": "2026-01-24T09:29:14.566489+00:00"}
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9526, "timestamp": "2026-01-24T09:29:14.644145+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9584, "timestamp": "2026-01-24T09:29:14.754356+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9576, "timestamp": "2026-01-24T09:29:24.497271+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 833.3828125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9576, "timestamp": "2026-01-24T09:29:24.498245+00:00"}
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 9584, "timestamp": "2026-01-24T09:29:24.564175+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 833.5, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9584, "timestamp": "2026-01-24T09:29:24.565137+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9636, "timestamp": "2026-01-24T09:29:24.606310+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9638, "timestamp": "2026-01-24T09:29:24.609368+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9636, "timestamp": "2026-01-24T09:29:34.608176+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9636, "timestamp": "2026-01-24T09:29:34.608385+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9638, "timestamp": "2026-01-24T09:29:34.610188+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9638, "timestamp": "2026-01-24T09:29:34.611012+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 880.95703125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9638, "timestamp": "2026-01-24T09:29:34.611430+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9636, "timestamp": "2026-01-24T09:29:34.663941+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9638, "timestamp": "2026-01-24T09:29:34.665169+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9636, "timestamp": "2026-01-24T09:29:35.109435+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 9638, "timestamp": "2026-01-24T09:29:35.111596+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9692, "timestamp": "2026-01-24T09:29:35.164227+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 9694, "timestamp": "2026-01-24T09:29:35.169465+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9692, "timestamp": "2026-01-24T09:29:45.165392+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9692, "timestamp": "2026-01-24T09:29:45.165595+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 844.52734375, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 9692, "timestamp": "2026-01-24T09:29:45.166148+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 9694, "timestamp": "2026-01-24T09:29:45.170619+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 9694, "timestamp": "2026-01-24T09:29:45.170745+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9692, "timestamp": "2026-01-24T09:29:45.221142+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 9694, "timestamp": "2026-01-24T09:29:45.224559+00:00"}
# ...
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11178, "timestamp": "2026-01-24T09:34:13.006711+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 11129, "timestamp": "2026-01-24T09:34:13.157439+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11181, "timestamp": "2026-01-24T09:34:13.215162+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 11178, "timestamp": "2026-01-24T09:34:23.007446+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 11178, "timestamp": "2026-01-24T09:34:23.008063+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 871.3125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 11178, "timestamp": "2026-01-24T09:34:23.008615+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 11178, "timestamp": "2026-01-24T09:34:23.101916+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 11181, "timestamp": "2026-01-24T09:34:23.216408+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 11181, "timestamp": "2026-01-24T09:34:23.216603+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 871.3125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 11181, "timestamp": "2026-01-24T09:34:23.217137+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 11181, "timestamp": "2026-01-24T09:34:23.270724+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 11178, "timestamp": "2026-01-24T09:34:23.509079+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11230, "timestamp": "2026-01-24T09:34:23.587579+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 11181, "timestamp": "2026-01-24T09:34:23.717494+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11237, "timestamp": "2026-01-24T09:34:23.792311+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 11230, "timestamp": "2026-01-24T09:34:33.021302+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 833.3828125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 11230, "timestamp": "2026-01-24T09:34:33.022266+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11286, "timestamp": "2026-01-24T09:34:33.043284+00:00"}
# Using device cuda
# Using backend lmdeploy
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 219, in initialize\n    raise RuntimeError(f\"process initialization failed: {init_res.error}\")\nRuntimeError: process initialization failed: No module named 'lmdeploy'", "pid": 11237, "timestamp": "2026-01-24T09:34:33.316000+00:00"}
# {"message": "process memory usage is high", "level": "WARNING", "name": "livekit.agents", "memory_usage_mb": 832.33203125, "memory_warn_mb": 500, "memory_limit_mb": 0, "pid": 11237, "timestamp": "2026-01-24T09:34:33.316973+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11291, "timestamp": "2026-01-24T09:34:33.346298+00:00"}
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# /project/sherpa-onnx/csrc/session.cc:GetSessionOptionsImpl:182 Please compile with -DSHERPA_ONNX_ENABLE_GPU=ON. Available providers: CPUExecutionProvider, . Fallback to cpu!
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 11286, "timestamp": "2026-01-24T09:34:43.044413+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 11286, "timestamp": "2026-01-24T09:34:43.044594+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 11286, "timestamp": "2026-01-24T09:34:43.112914+00:00"}
# {"message": "killing process", "level": "INFO", "name": "livekit.agents", "pid": 11291, "timestamp": "2026-01-24T09:34:43.346950+00:00"}
# {"message": "sending SIGUSR1 signal to process", "level": "INFO", "name": "livekit.agents", "pid": 11291, "timestamp": "2026-01-24T09:34:43.347196+00:00"}
# {"message": "process exited with non-zero exit code -10", "level": "ERROR", "name": "livekit.agents", "pid": 11291, "timestamp": "2026-01-24T09:34:43.382067+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 11286, "timestamp": "2026-01-24T09:34:43.545802+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11340, "timestamp": "2026-01-24T09:34:43.583250+00:00"}
# {"message": "error initializing process", "level": "ERROR", "name": "livekit.agents", "exc_info": "Traceback (most recent call last):\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 520, in wait_for\n    return await fut\n           ^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/channel.py\", line 47, in arecv_message\n    return _read_message(await dplx.recv_bytes(), messages)\n                         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/utils/aio/duplex_unix.py\", line 35, in recv_bytes\n    len_bytes = await self._reader.readexactly(4)\n                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 752, in readexactly\n    await self._wait_for_data('readexactly')\n  File \"/usr/lib/python3.12/asyncio/streams.py\", line 545, in _wait_for_data\n    await self._waiter\nasyncio.exceptions.CancelledError\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/proc_pool.py\", line 171, in _proc_spawn_task\n    await proc.initialize()\n  File \"/usr/local/lib/python3.12/dist-packages/livekit/agents/ipc/supervised_proc.py\", line 210, in initialize\n    init_res = await asyncio.wait_for(\n               ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 519, in wait_for\n    async with timeouts.timeout(timeout):\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/timeouts.py\", line 115, in __aexit__\n    raise TimeoutError from exc_val\nTimeoutError", "pid": 11291, "timestamp": "2026-01-24T09:34:43.848281+00:00"}
# {"message": "initializing process", "level": "INFO", "name": "livekit.agents", "pid": 11347, "timestamp": "2026-01-24T09:34:43.889338+00:00"}
# {"message": "exiting forcefully", "level": "WARNING", "name": "livekit.agents", "timestamp": "2026-01-24T09:34:49.181395+00:00"}

# %% [markdown]
# ## 7. Alternative: Save as Python Script and Run
#
# For production use, save the agent as a Python script and run it from the command line.

# %%
# Save the complete agent script
AGENT_SCRIPT = '''
"""LiveKit Agents: STT → Gemini Flash → Soprano TTS Pipeline"""

import os
import re
import numpy as np
from typing import AsyncIterable, Optional, List

from livekit import agents, rtc
from livekit.agents import Agent, AgentSession, ModelSettings, stt
from livekit.agents.cli import WorkerOptions, cli
from livekit.plugins import google, silero
from google.genai.types import Modality

import sherpa_onnx
from soprano import SopranoTTS


def _pick_existing(*paths: str) -> str:
    for p in paths:
        if p and os.path.exists(p):
            return p
    raise FileNotFoundError(f"None of these paths exist: {paths}")


def _load_sherpa_recognizer(model_dir: str) -> sherpa_onnx.OnlineRecognizer:
    base96 = os.path.join(model_dir, "96")
    base = base96 if os.path.isdir(base96) else model_dir

    tokens = _pick_existing(
        os.path.join(model_dir, "tokens.txt"),
        os.path.join(base, "tokens.txt"),
    )
    encoder = _pick_existing(
        os.path.join(base, "encoder-epoch-99-avg-1.int8.onnx"),
        os.path.join(model_dir, "encoder-epoch-99-avg-1.int8.onnx"),
        os.path.join(base, "encoder-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "encoder-epoch-99-avg-1.onnx"),
    )
    decoder = _pick_existing(
        os.path.join(base, "decoder-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "decoder-epoch-99-avg-1.onnx"),
    )
    joiner = _pick_existing(
        os.path.join(base, "joiner-epoch-99-avg-1.int8.onnx"),
        os.path.join(model_dir, "joiner-epoch-99-avg-1.int8.onnx"),
        os.path.join(base, "joiner-epoch-99-avg-1.onnx"),
        os.path.join(model_dir, "joiner-epoch-99-avg-1.onnx"),
    )

    return sherpa_onnx.OnlineRecognizer.from_transducer(
        tokens=tokens,
        encoder=encoder,
        decoder=decoder,
        joiner=joiner,
        num_threads=int(os.getenv("SHERPA_NUM_THREADS", "2")),
        provider=os.getenv("SHERPA_PROVIDER", "cuda"),
        decoding_method="greedy_search",
        max_active_paths=4,
        enable_endpoint=False,
    )


class FastPipelineAgent(Agent):
    def __init__(self, *, sherpa_recognizer, soprano):
        super().__init__()
        self._sherpa = sherpa_recognizer
        self._soprano = soprano
        self._sent_re = re.compile(r"(.+?[.!?]\\s+|.+?\\n+)", re.DOTALL)

    async def stt_node(self, audio, model_settings):
        async def _run():
            stream = self._sherpa.create_stream()
            last_text = ""
            async for frame in audio:
                samples_i16 = np.frombuffer(frame.data, dtype=np.int16)
                samples_f32 = samples_i16.astype(np.float32) / 32768.0
                stream.accept_waveform(frame.sample_rate, samples_f32)
                while self._sherpa.is_ready(stream):
                    self._sherpa.decode_stream(stream)
                    r = self._sherpa.get_result(stream)
                    text = r if isinstance(r, str) else getattr(r, "text", "")
                    if text and text != last_text:
                        last_text = text
            stream.input_finished()
            while self._sherpa.is_ready(stream):
                self._sherpa.decode_stream(stream)
            r = self._sherpa.get_result(stream)
            final_text = r if isinstance(r, str) else getattr(r, "text", "")
            if final_text.strip():
                yield stt.SpeechEvent(
                    type=stt.SpeechEventType.FINAL_TRANSCRIPT,
                    alternatives=[stt.SpeechData(text=final_text)],
                )
            yield stt.SpeechEvent(type=stt.SpeechEventType.END_OF_SPEECH, alternatives=[])
        return _run()

    async def tts_node(self, text, model_settings):
        buffer = ""
        sample_rate = 32000
        spf = int(sample_rate * 20 / 1000)

        async def _emit(pcm_f32):
            pcm_i16 = (np.clip(pcm_f32, -1.0, 1.0) * 32767.0).astype(np.int16)
            idx = 0
            while idx < pcm_i16.shape[0]:
                chunk = pcm_i16[idx:idx + spf]
                if chunk.shape[0] < spf:
                    chunk = np.concatenate([chunk, np.zeros(spf - chunk.shape[0], dtype=np.int16)])
                idx += spf
                yield rtc.AudioFrame(data=chunk.tobytes(), sample_rate=sample_rate, num_channels=1, samples_per_channel=spf)

        async def _speak(sentence):
            for chunk in self._soprano.infer_stream(sentence, chunk_size=1):
                pcm = chunk.astype(np.float32) if isinstance(chunk, np.ndarray) else np.asarray(chunk, dtype=np.float32)
                async for frame in _emit(pcm):
                    yield frame

        async for delta in text:
            buffer += delta
            while True:
                m = self._sent_re.match(buffer)
                if not m:
                    break
                s = m.group(1)
                buffer = buffer[len(s):]
                async for frame in _speak(s):
                    yield frame
        if buffer.strip():
            async for frame in _speak(buffer):
                yield frame


def prewarm(proc):
    proc.userdata["vad"] = silero.VAD.load(min_speech_duration=0.05, min_silence_duration=0.35, force_cpu=True)
    proc.userdata["sherpa"] = _load_sherpa_recognizer(os.environ["SHERPA_MODEL_DIR"])
    proc.userdata["soprano"] = SopranoTTS(
        backend=os.getenv("SOPRANO_BACKEND", "lmdeploy"),
        device=os.getenv("SOPRANO_DEVICE", "cuda"),
        cache_size_mb=int(os.getenv("SOPRANO_CACHE_MB", "512")),
        decoder_batch_size=int(os.getenv("SOPRANO_DECODER_BS", "2")),
    )


async def entrypoint(ctx):
    agent = FastPipelineAgent(
        sherpa_recognizer=ctx.proc.userdata["sherpa"],
        soprano=ctx.proc.userdata["soprano"],
    )
    session = AgentSession(
        turn_detection="vad",
        vad=ctx.proc.userdata["vad"],
        llm=google.realtime.RealtimeModel(
            model=os.getenv("GEMINI_MODEL", "gemini-2.5-flash"),
            modalities=[Modality.TEXT],
            instructions=os.getenv("SYSTEM_PROMPT", "You are a concise, helpful voice assistant."),
            temperature=float(os.getenv("GEMINI_TEMPERATURE", "0.3")),
        ),
        preemptive_generation=True,
    )
    await session.start(agent=agent, room=ctx.room)


if __name__ == "__main__":
    cli.run_app(WorkerOptions(entrypoint_fnc=entrypoint, prewarm_fnc=prewarm))
'''

with open('fast_agent.py', 'w') as f:
    f.write(AGENT_SCRIPT)

print("✅ Agent script saved to fast_agent.py")
print("\nTo run: python fast_agent.py dev")

# %% [markdown]
# ## Reference Links
#
# - [LiveKit Agents: Pipeline Nodes](https://docs.livekit.io/agents/logic/nodes/)
# - [LiveKit Gemini Live API Plugin](https://docs.livekit.io/agents/models/realtime/plugins/gemini/)
# - [LiveKit Silero VAD Plugin](https://docs.livekit.io/agents/build/turns/vad/)
# - [Turn Detection Configuration](https://docs.livekit.io/agents/v1/build/turn-detection/configuration)
# - [sherpa-onnx Streaming Zipformer Models](https://k2-fsa.github.io/sherpa/onnx/pretrained_models/online-transducer/zipformer-transducer-models.html)
# - [Soprano Model Card](https://huggingface.co/ekwek/Soprano-1.1-80M)
